# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Bruno/PlanejamentoDeExperimentos/blob/main/Jose_Bruno_da_Silva_Santos%20-%20Atividade%20Avaliativa%20S7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Capa.jpg](data:image/jpeg;base64,...)

# %%
#Importa as bibliotecas necessarias para a criação dos gráficos
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sn

# %% [markdown]
# ![q1.jpg](data:image/jpeg;base64,...)

# %%
#Salva o dataset na variavel arquivo1 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo1 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/weight_chart.txt', sep='\t')
age = arquivo1['Age']         #Salva os valores da tabela Age do dataset na variavel age 
weight = arquivo1['Weight']    #Salva os valores da tabela Weight do dataset na variavel weight

# %%
plt.figure(figsize=(8,6))           #Define o tamanho da imagem do grafico 
plt.plot(age, weight, marker='o')   #Defini o eixo X e o eixo Y alem do marcador dos pontos no plot
plt.yticks([0,2,4,6,8,10])          #Defini a escala do eixo Y
plt.xticks([0,2,4,6,8])             #Defini a escala do eixo X
plt.title("The Relationship between age and weight in a growinfg infant") #Define o titulo do gráfico
plt.xlabel("Age (months)")          #Define o titulo do eixo X do gráfico
plt.ylabel("Weight (kg)")           #Define o titulo do eixo Y do gráfico
plt.show()                          #Exibe o gráfico

# %% [markdown]
# ![q2.jpg](data:image/jpeg;base64,...)

# %%
#Salva o dataset na variavel arquivo2 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo2 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/feature_counts.txt', sep='\t')
feature = arquivo2['Feature']            #Salva os valores da tabela Feature do dataset na variavel feature
count = arquivo2['Count']                #Salva os valores da tabela Count do dataset na variavel count

# %%
plt.figure(figsize=(8,6))               #Define o tamanho da imagem do grafico 
plt.xlabel("Number of features")        # #Define o titulo do eixo X do gráfico
plt.barh(feature, count, color='gray')  #Defini o eixo X e o eixo Y alem de selecionar a cor do gráfico
plt.xticks([0,20000,40000,60000])       #Defini a escala do eixo X
# Out:
# ([<matplotlib.axis.XTick at 0x7fb8780d7a90>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# ![q3.jpg](data:image/jpeg;base64,...)

# %%
distribuicao1 = np.random.normal(size=10000)  #Gera um,a distribuição normal atravez da biblioteca Numpy
distribuicao2 = distribuicao1 + 4             #Gera uma segunda distribuição com a junção a 1 distribução gerada com um deslçocamento de + 4
plt.figure(figsize=(10,8))                    #Define o tamanho da imagem do grafico
sn.histplot(np.concatenate((distribuicao1,distribuicao2)), bins=130, color='gray', ec='black') #Defini o eixo X e o eixo Y alem de selecionar a cor do gráfico e sua proporção
plt.title("Mixed distribuition histogram")    #Define o titulo do gráfico
plt.xlabel("Values")                          #Define o titulo do eixo X do gráfico
plt.ylabel("Frequency")                       #Define o titulo do eixo Y do gráfico
plt.xticks([-4, -2, 0, 2, 4, 6, 8])           #Defini a escala do eixo X
plt.yticks([0, 100, 200, 300, 400])           #Defini a escala do eixo Y
plt.show()                                    #Exibe o gráfico

# %% [markdown]
# ![q4.jpg](data:image/jpeg;base64,...)

# %%
#Salva o dataset na variavel arquivo4 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo4 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/male_female_counts.txt', sep='\t')
sample = arquivo4['Sample']   #Salva os valores da tabela Sample do dataset na variavel sample
count = arquivo4['Count']     #Salva os valores da tabela Count do dataset na variavel count

# %%
plt.figure(figsize=(15,6))    #Define o tamanho da imagem do grafico 
plt.bar(sample, count, color=['red', 'orange', 'yellow','lime', 'springgreen', 'aquamarine', 'blue', 'navy', 'purple', 'magenta'])    #Defini o eixo X e o eixo Y alem de selecionar as cores do gráfico
plt.yticks([0,5,10,15])       #Defini a escala do eixo Y
plt.show()                    #Exibe o gráfico

# %% [markdown]
# ![q5.jpg](data:image/jpeg;base64,...)

# %%
#Salva o dataset na variavel arquivo5 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo5 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/up_down_expression.txt', sep='\t')
gene = arquivo5['Gene']               #Salva os valores da tabela Gene do dataset na variavel gene
condition1 = arquivo5['Condition1']   #Salva os valores da tabela Condition1 do dataset na variavel condition1 
condition2 = arquivo5['Condition2']   #Salva os valores da tabela Condition2 do dataset na variavel condition2 
state = arquivo5['State']             #Salva os valores da tabela State do dataset na variavel state

# %%
state_unchanging = arquivo5.loc[arquivo5['State']=='unchanging']  #Seleciona apenas as instacias com o status 'unchanging' do arquivo
state_up = arquivo5.loc[arquivo5['State']=='up']                  #Seleciona apenas as instacias com o status 'up' do arquivo
state_down = arquivo5.loc[arquivo5['State']=='down']              #Seleciona apenas as instacias com o status 'down' do arquivo

# %%
plt.figure(figsize=(8,6))   #Define o tamanho da imagem do grafico 
plt.scatter(state_unchanging.Condition1, state_unchanging.Condition2, color='grey', s=5)   #Defini o eixo X e o eixo Y do state 'unchanging' da condição 1 e 2 e selciona a cor dos pontos
plt.scatter(state_up.Condition1, state_up.Condition2, color='red', s=5)                    #Defini o eixo X e o eixo Y do state 'up' da condição 1 e 2 e selciona a cor dos pontos
plt.scatter(state_down.Condition1, state_down.Condition2, color='blue', s=5)               #Defini o eixo X e o eixo Y do state 'down' da condição 1 e 2 e selciona a cor dos pontos
plt.xlabel("Condition 1")    #Define o titulo do eixo X do gráfico
plt.ylabel("Condition 2")    #Define o titulo do eixo Y do gráfico
plt.xticks([0,5,10])         #Defini a escala do eixo X
plt.yticks([0,5,10])         #Defini a escala do eixo Y
plt.show()                   #Exibe o gráfico

# %% [markdown]
# ![q6.jpg](data:image/jpeg;base64,...)

# %%
#salva o dataset na variavel arquivo6 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo6 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/chromosome_position_data.txt', sep='\t')
position = arquivo6['Position']   #Salva os valores da tabela Position do dataset na variavel position
mut1 = arquivo6['Mut1']           #Salva os valores da tabela Mult1 do dataset na variavel mut1
mut2 = arquivo6['Mut2']           #Salva os valores da tabela Mult2 do dataset na variavel mult2
wt = arquivo6['WT']               #Salva os valores da tabela WT do dataset na variavel wt

# %%
plt.figure(figsize=(8,6))                             #Define o tamanho da imagem do grafico 
plt.plot(position,mut1, color="red", label="Mult1")   #Defini o eixo X e o eixo Y de Mul1 selciona a cor da linha e defini a legenda
plt.plot(position,wt, color="blue",label="Mult2")     #Defini o eixo X e o eixo Y de Mul2 selciona a cor da linha e defini a legenda
plt.plot(position,mut2, color="green", label="WP")    #Defini o eixo X e o eixo Y de WP selciona a cor da linha e defini a legenda
plt.legend()                                          #Plota a legenda
plt.xlabel("Position whithin chromosome")             #Define o titulo do eixo X do gráfico 
plt.ylabel("value")                                   #Define o titulo do eixo Y do gráfico
plt.show()                                            #Exibe o gráfico

# %% [markdown]
# ![q7.jpg](data:image/jpeg;base64,...)

# %%
#salva o dataset na variavel arquivo7 que faz a leitura diretamente do repositorio do github atraves da biblioteca pandas
arquivo7 = pd.read_csv('https://raw.githubusercontent.com/androidpcguy/bggn213/master/class05/bimm143_05_rstats/brain_bodyweight.txt', sep='\t')

# %%
plt.figure(figsize=(8,8))   #Define o tamanho da imagem do grafico

#É feito um loop nos valores onde são armazenados em suas respsctivas variaveis cada atributo.
#É feito o calculo do errorbar, juntamente com o caclulo da posição de cada item para sua respectiva apresentação no grafica
for x in arquivo7.values:
  species = x[0]
  bodyweight = x[1]
  brainweight = x[2]
  bodyweightSEM = x[3]
  brainweightSEM = x[4]
  plt.errorbar(y=bodyweight, x=brainweight, yerr=bodyweightSEM, xerr=brainweightSEM, color='black', marker='h' )
  plt.annotate(species, (brainweight - 0.20, bodyweight - 0.3), fontsize = 'small')

plt.xlabel("Brain weight")      #Define o titulo do eixo X do gráfico
plt.ylabel("Body weight")       #Define o titulo do eixo Y do gráfico
plt.xticks([0,1,2,3])           #Defini a escala do eixo X
plt.yticks([-1,0,1,2,3,4,5])    #Defini a escala do eixo Y
plt.show()                      #Exibe o gráfico
